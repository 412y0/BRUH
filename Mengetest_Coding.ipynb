# %%
#INPUT
'nama         : Aryo Kusumo Priambodo'
'NIM          : 2605060059'
'T.T.L        : KOTA MAGELANG, 23 Oktober 2007'
'Jensi Kelamin: Laki-Laki'
'Alamat       : Gg. Potrosaran II/I'
'Hobi         : Mendengarkan musik'

# %%
#MENGEPRINT
print('nama          : Aryo Kusumo Priambodo')
print('NIM           : 2605060059')
print(" ")
print('Jensi Kelamin : Laki-Laki')
print('Alamat        : Gg. Potrosaran II/I')
print('Hobi          : Mendengarkan musik')
print(" ")
print(" ")
print('Sekian Terimakasih :)')
# Out:
# nama          : Aryo Kusumo Priambodo
# NIM           : 2605060059
#
# Jensi Kelamin : Laki-Laki
# Alamat        : Gg. Potrosaran II/I
# Hobi          : Mendengarkan musik
#
#
# Sekian Terimakasih :)
